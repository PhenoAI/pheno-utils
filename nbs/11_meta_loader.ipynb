# %% [raw]
# ---
# description: Load dataset dictionaries and access all datasets and fields in a flexible manner.
# output-file: meta_loader.html
# title: Metadata loader
#
# ---

# %%
#| default_exp meta_loader

# %%
#| hide
from nbdev.showdoc import *

# %%
#| export
import os
import re
from typing import List, Any, Dict, Union
import warnings

import numpy as np
import pandas as pd
import dask.dataframe as dd

# %%
#| export
from pheno_utils.config import (
    DATASETS_PATH, 
    COHORT, 
    ERROR_ACTION
    )
from pheno_utils.pheno_loader import PhenoLoader

# %%
#| export

class MetaLoader:
    """
    Class to load multiple dictionaries and allows to easily access the relevant fields.

    Args:
    
        base_path (str, optional): The base path where the data is stored. Defaults to DATASETS_PATH.
        cohort (str, optional): The name of the cohort within the dataset. Defaults to COHORT.
        flexible_field_search (bool, optional): Whether to allow regex field search. Defaults to False.
        errors (str, optional): Whether to raise an error or issue a warning if missing data is encountered.
            Possible values are 'raise', 'warn' and 'ignore'. Defaults to 'raise'.
        **kwargs: Additional keyword arguments to pass to a DataLoader class.

    Attributes:
    
        dicts (pd.DataFrame): A dictionary of data dictionaries (dataframes) of all availbale datasets in the base_path.
        fields (list): A list of all fields.
        cohort (str): The name of the cohort being used.
        base_path (str): The base path where the data is stored.
        flexible_field_search (bool): Whether to allow regex field search.
        errors (str): Whether to raise an error or issue a warning if missing data is encountered.
        kwargs (dict): Additional keyword arguments to pass to a DataLoader class.
    """

    def __init__(
        self,
        base_path: str = DATASETS_PATH,
        cohort: str = COHORT,
        flexible_field_search: bool = False,
        errors: str = ERROR_ACTION,
        **kwargs,
    ) -> None:
        self.cohort = cohort
        self.base_path = base_path
        self.dataset_path = self.__get_dataset_path__()
        
        self.flexible_field_search = flexible_field_search
        self.errors = errors
        self.kwargs = kwargs

        self.__load_dictionaries__()

    def load(self, fields: Union[str,List[str]], flexible: bool=None, prop: str='tabular_field_name') -> pd.DataFrame:
        """
        Return a dataframe containing the fields from the respective datasets.

        Args:
            fields (Union[str,List[str]]): Fields to return
            flexible (bool, optional): Whether to use fuzzy matching to find fields. Defaults to None, which uses the DataLoader's flexible_field_search attribute.
            prop (str, optional): The property to use for searching. Defaults to 'tabular_field_name'.

        Returns:
            pd.DataFrame: Dataframe containing the fields from the respective datasets.
        """
        found_fields = self.get(fields, flexible, prop)
        if found_fields.empty:
            return pd.DataFrame()

        found_fields.columns = found_fields.columns.str.split('/').str[1]
        dup_fields = found_fields.columns.value_counts()\
            .to_frame('count').query('count > 1').index
        n_datasets = found_fields.loc['dataset'].nunique()

        loaded_fields = []
        for ds, f in found_fields.T.groupby('dataset'):
            df = PhenoLoader(ds, base_path=self.base_path, cohort=self.cohort,
                             age_sex_dataset=None, **self.kwargs)\
                [f.index.tolist()]
            if df.empty:
                continue

            if 'array_index' in df.index.names and n_datasets > 1:
                if df.index.get_level_values('array_index').nunique() > 1:
                    df = df.reset_index('array_index', drop=False)\
                        .rename(columns={'array_index': f'{ds}__array_index'})
                else:
                    df = df.reset_index('array_index', drop=True)

            # rename duplicate fields
            df = df.rename(columns=pd.Series(f'{ds}__' + dup_fields, index=dup_fields))

            if not len(loaded_fields):
                loaded_fields = df
                continue

            loaded_fields = loaded_fields.join(df, how='outer')

        return loaded_fields

    def get(self, fields: Union[str,List[str]], flexible: bool=None, prop='tabular_field_name') -> pd.DataFrame:
        """
        Return metadata for the specified fields from all tables.

        Args:
            fields (List[str]): Fields to return
            flexible (bool, optional): Whether to use fuzzy matching to find fields. Defaults to None, which uses the DataLoader's flexible_field_search attribute.
            prop (str, optional): The property to use for searching. Defaults to 'tabular_field_name'.

        Returns:
            pd.DataFrame: Data for the specified fields from all tables
        """
        if flexible is None:
            flexible = self.flexible_field_search
        if isinstance(fields, str):
            fields = [fields]
        fields = pd.DataFrame({'field': [f.lower() for f in fields]}).assign(dataset=None)

        if prop == 'tabular_field_name':
            ind = fields['field'].str.contains('/')
            fields.loc[ind, 'dataset'] = fields.loc[ind, 'field'].str.split('/').str[0]
            fields.loc[ind, 'field'] = fields.loc[ind, 'field'].str.split('/').str[1]

        data = pd.DataFrame()
        for dataset, df in self.dicts.items():
            keep = (fields['dataset'] == dataset) | fields['dataset'].isnull()
            fields_in_dataset = fields.loc[keep, 'field']

            if prop == 'tabular_field_name':
                search_in = pd.Series(df.columns, index=df.columns).str.lower()
            else:
                search_in = df.loc[prop].dropna().str.lower()
            if flexible:
                # use fuzzy matching including regex to find fields
                fields_in_col = np.unique([col for f in fields_in_dataset for col, text in search_in.items()
                                           if type(text) is str and re.search(f, text)])
            else:
                fields_in_col = search_in[search_in.isin(fields_in_dataset)].index

            if len(fields_in_col):
                this_data = df[fields_in_col]
                this_data.columns = dataset + '/' + this_data.columns
                data = self.__concat__(data, this_data)

        return data

    def __repr__(self):
        """
        Return string representation of object

        Returns:
            str: String representation of object
        """
        return self.__str__()

    def __str__(self):
        """
        Return string representation of object

        Returns:
            str: String representation of object
        """
        ds_list = str(list(self.dicts.keys())).replace(',', '\n')
        return f'MetaLoader for: {self.dataset_path}\n' + \
            f'with {len(self.fields)} fields\n{len(self.dicts)} datasets:\n{ds_list}'

    def __getitem__(self, fields: Union[str,List[str]]):
        """
        Return data for the specified fields from all tables

        Args:
            fields (Union[str, List[str]]): Fields to return

        Returns:
            pd.DataFrame: Data for the specified fields from all tables
        """
        return self.get(fields)

    def __concat__(self, df1, df2):
        if df1.empty:
            return df2
        if df2.empty:
            return df1
        return df1.join(df2, how='outer')

    def __load_dictionaries__(self) -> None:
        """
        Load all dictionaries in the base_path.
        """
        dicts = dd.read_csv(os.path.join(self.dataset_path, 'metadata', '*_dict*.csv'),
                            include_path_column=True, dtype={'parent_dataframe': 'object', 'sampling_rate': 'object'}).compute()
        if self.cohort is None:
            dataset_ind = -3
        else:
            dataset_ind = -4
        dicts['dataset'] = dicts['path'].str.split('/').str[dataset_ind]
        dicts = dicts.drop(columns=['path'])
        self.fields = dicts['tabular_field_name'].unique()

        self.dicts = {}
        col_order = ['dataset'] + dicts.columns.drop('dataset').tolist()
        for dataset in dicts['dataset'].unique():
            self.dicts[dataset] = dicts.loc[dicts['dataset'] == dataset, col_order].set_index('tabular_field_name').T

    def __get_dataset_path__(self):
        """
        Get the dataset path.

        Args:
            dataset (str): the name of the dataset

        Returns:
            str: the path to the dataset
        """
        if self.cohort is not None:
            return os.path.join(self.base_path, '*', self.cohort)
        return os.path.join(self.base_path, '*')

# %%
# os.path.join(DATASETS_PATH, '*')
os.listdir(DATASETS_PATH)
# Out:
# ['cgm', 'diet_logging', 'events', 'fundus', 'sleep']

# %% [markdown]
# The `MetaLoader` can be used to query all availbale fields throughout all datasets. In the following example, 3 datasets are available.

# %%
ml = MetaLoader()
ml
# Out:
# MetaLoader for: examples/*
# with 83 fields
# 4 datasets:
# ['cgm'
#  'diet_logging'
#  'fundus'
#  'sleep']

# %% [markdown]
# The object contains only the data dictionaries (metadata) of these datasets, where the columns correspond to columns in the data tables of the dataset (e.g., fundus).

# %%
ml.dicts['fundus']
# Out:
# tabular_field_name      fundus_image_left     fundus_image_right  \
# dataset                            fundus                 fundus
# field_string          Fundus image (left)   Fundus image (right)
# description_string    Fundus image (left)   Fundus image (right)
# parent_dataframe                     <NA>                   <NA>
# relative_location   fundus/fundus.parquet  fundus/fundus.parquet
# value_type                          Text                   Text
# units                                <NA>                   <NA>
# sampling_rate                        <NA>                   <NA>
# item_type                            Bulk                   Bulk
# array                              Single                 Single
# cohorts                               10K                    10K
# data_type                           image                  image
# debut                          2021-02-17             2021-02-17
# pandas_dtype                       string                 string
#
# tabular_field_name               collection_date    fractal_dimension_left  \
# dataset                                   fundus                    fundus
# field_string        Collection date (YYYY-MM-DD)  Fractal dimension (left)
# description_string  Collection date (YYYY-MM-DD)  Fractal dimension (left)
# parent_dataframe                            <NA>                      <NA>
# relative_location          fundus/fundus.parquet     fundus/fundus.parquet
# value_type                                  Date                Continuous
# units                                       Time                      Time
# sampling_rate                               <NA>                      <NA>
# item_type                                   Data                      Data
# array                                     Single                    Single
# cohorts                                      10K                       10K
# data_type                                tabular                   tabular
# debut                                 2021-02-17                2021-02-17
# pandas_dtype                      datetime64[ns]                     float
#
# tabular_field_name    fractal_dimension_right
# dataset                                fundus
# field_string        Fractal dimension (right)
# description_string  Fractal dimension (right)
# parent_dataframe                         <NA>
# relative_location       fundus/fundus.parquet
# value_type                         Continuous
# units                                    Time
# sampling_rate                            <NA>
# item_type                                Data
# array                                  Single
# cohorts                                   10K
# data_type                             tabular
# debut                              2021-02-17
# pandas_dtype                            float

# %% [markdown]
# You can query fields from multiple datasets directly.

# %%
ml[['glucose', 'fundus_image_left', 'fundus/collection_date']]
# Out:
# tabular_field_name                  cgm/glucose fundus/fundus_image_left  \
# dataset                                     cgm                   fundus
# field_string                            Glucose      Fundus image (left)
# description_string  cgm temporal glucose values      Fundus image (left)
# parent_dataframe                           <NA>                     <NA>
# relative_location               cgm/cgm.parquet    fundus/fundus.parquet
# value_type               Series data, continous                    Text
# units                                     mg/dl                     <NA>
# sampling_rate                             15min                     <NA>
# item_type                                  Data                     Bulk
# array                                    Single                   Single
# cohorts                                     10K                      10K
# data_type                           time series                    image
# debut                                2018-12-27               2021-02-17
# pandas_dtype                              float                   string
#
# tabular_field_name        fundus/collection_date
# dataset                                   fundus
# field_string        Collection date (YYYY-MM-DD)
# description_string  Collection date (YYYY-MM-DD)
# parent_dataframe                            <NA>
# relative_location          fundus/fundus.parquet
# value_type                                  Date
# units                                       Time
# sampling_rate                               <NA>
# item_type                                   Data
# array                                     Single
# cohorts                                      10K
# data_type                                tabular
# debut                                 2021-02-17
# pandas_dtype                      datetime64[ns]

# %% [markdown]
# Note that in the example above, for `collection_date` (that is common to all datasets) the dataset is specified in the prefix `fundus/`. Therefore, the loader returns the field from the fundus imaging dataset. Omitting this prefix will return all `collection_date` fields in the Human Phenotype Project.
#
# You can then use the `MetaLoader` to load the actual data of fields from multiple datasets. Here we load `glucose` from the CGM dataset, and `fundus_image_left` from the fundus dataset.

# %%
ml.load(['glucose' ,'fundus_image_left', 'fundus/collection_date']).head()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/ec2-user/workspace/pheno-utils/nbs/11_meta_loader.ipynb Cell 15 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B34.252.143.28/home/ec2-user/workspace/pheno-utils/nbs/11_meta_loader.ipynb#X45sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> ml.load(['glucose' ,'fundus_image_left', 'fundus/collection_date']).head()
#
# /home/ec2-user/workspace/pheno-utils/nbs/11_meta_loader.ipynb Cell 15 line 6
#      <a href='vscode-notebook-cell://ssh-remote%2B34.252.143.28/home/ec2-user/workspace/pheno-utils/nbs/11_meta_loader.ipynb#X45sdnNjb2RlLXJlbW90ZQ%3D%3D?line=65'>66</a> loaded_fields = []
#      <a href='vscode-notebook-cell://ssh-remote%2B34.252.143.28/home/ec2-user/workspace/pheno-utils/nbs/11_meta_loader.ipynb#X45sdnNjb2RlLXJlbW90ZQ%3D%3D?line=66'>67</a> for ds, f in found_fields.T.groupby('dataset'):
# ---> <a href='vscode-notebook-cell://ssh-remote%2B34.252.143.28/home/ec2-user/workspace/pheno-utils/nbs/11_meta_loader.ipynb#X45sdnNjb2RlLXJlbW90ZQ%3D%3D?line=67'>68</a>     df = PhenoLoader(ds, base_path=self.base_path, cohort=self.cohort,
#      <a href='vscode-notebook-cell://ssh-remote%2B34.252.143.28/home/ec2-user/workspace/pheno-utils/nbs/11_meta_loader.ipynb#X45sdnNjb2RlLXJlbW90ZQ%3D%3D?line=68'>69</a>                      age_sex_dataset=None, **self.kwargs)\
#      <a href='vscode-notebook-cell://ssh-remote%2B34.252.143.28/home/ec2-user/workspace/pheno-utils/nbs/11_meta_loader.ipynb#X45sdnNjb2RlLXJlbW90ZQ%3D%3D?line=69'>70</a>         [f.index.tolist()]
#      <a href='vscode-notebook-cell://ssh-remote%2B34.252.143.28/home/ec2-user/workspace/pheno-utils/nbs/11_meta_loader.ipynb#X45sdnNjb2RlLXJlbW90ZQ%3D%3D?line=70'>71</a>     if df.empty:
#      <a href='vscode-notebook-cell://ssh-remote%2B34.252.143.28/home/ec2-user/workspace/pheno-utils/nbs/11_meta_loader.ipynb#X45sdnNjb2RlLXJlbW90ZQ%3D%3D?line=71'>72</a>         continue
#
# File ~/miniconda3/lib/python3.11/site-packages/pheno_utils/pheno_loader.py:100, in PhenoLoader.__init__(self, dataset, base_path, cohort, age_sex_dataset, skip_dfs, unique_index, valid_dates, valid_stage, flexible_field_search, squeeze, errors, read_parquet_kwargs)
#      97 self.errors = errors
#      98 self.read_parquet_kwargs = read_parquet_kwargs
# --> 100 self.__load_dictionary__()
#     101 self.__load_dataframes__()
#     102 if self.age_sex_dataset is not None:
#
# File ~/miniconda3/lib/python3.11/site-packages/pheno_utils/pheno_loader.py:505, in PhenoLoader.__load_dictionary__(self)
#     501 def __load_dictionary__(self) -> None:
#     502     """
#     503     Load dataset dictionary.
#     504     """
# --> 505     self.dict = pd.read_csv(self.__get_dictionary_file_path__(self.dataset))\
#     506         .dropna(subset='tabular_field_name')\
#     507         .set_index('tabular_field_name')
#     509     if 'bulk_dictionary' not in self.dict.columns:
#     510         return
#
# File ~/miniconda3/lib/python3.11/site-packages/pheno_utils/pheno_loader.py:548, in PhenoLoader.__get_dictionary_file_path__(self, dataset)
#     546 if path.startswith('s3://'):
#     547    return path
# --> 548 return glob(path)[0]
#
# IndexError: list index out of range

# %% [markdown]
# You may use more flexible search queries using regex and various properties of the fields. Both the `get()` method and `load()` method support the same syntax.
#
# 1. Example: get all bulk data fields.

# %%
ml.get('bulk', flexible=True, prop='item_type')
# Out:
# tabular_field_name                                   cgm/cgm_filename  \
# dataset                                                           cgm
# field_string                                           CGM timeseries
# description_string  Name of the file containing the participants' ...
# parent_dataframe                                                 <NA>
# relative_location                                     cgm/cgm.parquet
# value_type                                                       Text
# units                                                            <NA>
# sampling_rate                                                    <NA>
# item_type                                                        Bulk
# array                                                          Single
# cohorts                                                           10K
# data_type                                                        text
# debut                                                      2018-12-27
# pandas_dtype                                                   string
#
# tabular_field_name fundus/fundus_image_left fundus/fundus_image_right
# dataset                              fundus                    fundus
# field_string            Fundus image (left)      Fundus image (right)
# description_string      Fundus image (left)      Fundus image (right)
# parent_dataframe                       <NA>                      <NA>
# relative_location     fundus/fundus.parquet     fundus/fundus.parquet
# value_type                            Text                      Text
# units                                  <NA>                      <NA>
# sampling_rate                          <NA>                      <NA>
# item_type                              Bulk                      Bulk
# array                                Single                    Single
# cohorts                                 10K                       10K
# data_type                             image                     image
# debut                            2021-02-17                2021-02-17
# pandas_dtype                         string                    string

# %% [markdown]
# 2. Example: get all fields that include "mg" in their units

# %%
ml.get('mg', flexible=True, prop='units')
# Out:
# tabular_field_name                            cgm/1st qu_  \
# dataset                                               cgm
# field_string                                 1st quantile
# description_string  First quantile of all glucose values.
# parent_dataframe                                     <NA>
# relative_location                         cgm/cgm.parquet
# value_type                                     Continuous
# units                                               mg/dl
# sampling_rate                                        <NA>
# item_type                                            Data
# array                                              Single
# cohorts                                               10K
# data_type                                         tabular
# debut                                          2018-12-27
# pandas_dtype                                        float
#
# tabular_field_name                            cgm/3rd qu_  \
# dataset                                               cgm
# field_string                                 3rd quantile
# description_string  Third quantile of all glucose values.
# parent_dataframe                                     <NA>
# relative_location                         cgm/cgm.parquet
# value_type                                     Continuous
# units                                               mg/dl
# sampling_rate                                        <NA>
# item_type                                            Data
# array                                              Single
# cohorts                                               10K
# data_type                                         tabular
# debut                                          2018-12-27
# pandas_dtype                                        float
#
# tabular_field_name                                            cgm/auc  \
# dataset                                                           cgm
# field_string                                                      AUC
# description_string  Hourly average AUC. This measure integrates, t...
# parent_dataframe                                                 <NA>
# relative_location                                     cgm/cgm.parquet
# value_type                                                 Continuous
# units                                                         mg/dl*h
# sampling_rate                                                    <NA>
# item_type                                                        Data
# array                                                          Single
# cohorts                                                           10K
# data_type                                                     tabular
# debut                                                      2018-12-27
# pandas_dtype                                                    float
#
# tabular_field_name                                           cgm/ea1c  \
# dataset                                                           cgm
# field_string                                                     eA1C
# description_string  A linear transformation of the mean glucose va...
# parent_dataframe                                                 <NA>
# relative_location                                     cgm/cgm.parquet
# value_type                                                 Continuous
# units                                                           mg/dl
# sampling_rate                                                    <NA>
# item_type                                                        Data
# array                                                          Single
# cohorts                                                           10K
# data_type                                                     tabular
# debut                                                      2018-12-27
# pandas_dtype                                                    float
#
# tabular_field_name                  cgm/glucose  \
# dataset                                     cgm
# field_string                            Glucose
# description_string  cgm temporal glucose values
# parent_dataframe                           <NA>
# relative_location               cgm/cgm.parquet
# value_type               Series data, continous
# units                                     mg/dl
# sampling_rate                             15min
# item_type                                  Data
# array                                    Single
# cohorts                                     10K
# data_type                           time series
# debut                                2018-12-27
# pandas_dtype                              float
#
# tabular_field_name                                            cgm/gmi  \
# dataset                                                           cgm
# field_string                                                      GMI
# description_string  A linear transformation of the mean glucose va...
# parent_dataframe                                                 <NA>
# relative_location                                     cgm/cgm.parquet
# value_type                                                 Continuous
# units                                                           mg/dl
# sampling_rate                                                    <NA>
# item_type                                                        Data
# array                                                          Single
# cohorts                                                           10K
# data_type                                                     tabular
# debut                                                      2018-12-27
# pandas_dtype                                                    float
#
# tabular_field_name                                            cgm/iqr  \
# dataset                                                           cgm
# field_string                                                      IQR
# description_string  Interquartile range (IQR), calculated as the d...
# parent_dataframe                                                 <NA>
# relative_location                                     cgm/cgm.parquet
# value_type                                                 Continuous
# units                                                           mg/dl
# sampling_rate                                                    <NA>
# item_type                                                        Data
# array                                                          Single
# cohorts                                                           10K
# data_type                                                     tabular
# debut                                                      2018-12-27
# pandas_dtype                                                    float
#
# tabular_field_name                                            cgm/mad  \
# dataset                                                           cgm
# field_string                                                      MAD
# description_string  Median Absolute Deviation (MAD). This is a mea...
# parent_dataframe                                                 <NA>
# relative_location                                     cgm/cgm.parquet
# value_type                                                 Continuous
# units                                                           mg/dl
# sampling_rate                                                    <NA>
# item_type                                                        Data
# array                                                          Single
# cohorts                                                           10K
# data_type                                                     tabular
# debut                                                      2018-12-27
# pandas_dtype                                                    float
#
# tabular_field_name                                            cgm/mag  \
# dataset                                                           cgm
# field_string                                                      MAG
# description_string  Mean Absolute Glucose (MAG). This is a measure...
# parent_dataframe                                                 <NA>
# relative_location                                     cgm/cgm.parquet
# value_type                                                 Continuous
# units                                                           mg/dl
# sampling_rate                                                    <NA>
# item_type                                                        Data
# array                                                          Single
# cohorts                                                           10K
# data_type                                                     tabular
# debut                                                      2018-12-27
# pandas_dtype                                                    float
#
# tabular_field_name                                           cgm/mage  ...  \
# dataset                                                           cgm  ...
# field_string                                                     MAGE  ...
# description_string  Mean Amplitude of Glycemic Excursions (MAGE), ...  ...
# parent_dataframe                                                 <NA>  ...
# relative_location                                     cgm/cgm.parquet  ...
# value_type                                                 Continuous  ...
# units                                                           mg/dl  ...
# sampling_rate                                                    <NA>  ...
# item_type                                                        Data  ...
# array                                                          Single  ...
# cohorts                                                           10K  ...
# data_type                                                     tabular  ...
# debut                                                      2018-12-27  ...
# pandas_dtype                                                    float  ...
#
# tabular_field_name                                           cgm/modd  \
# dataset                                                           cgm
# field_string                                                     MODD
# description_string  Mean difference between glucose values obtaine...
# parent_dataframe                                                 <NA>
# relative_location                                     cgm/cgm.parquet
# value_type                                                 Continuous
# units                                                           mg/dl
# sampling_rate                                                    <NA>
# item_type                                                        Data
# array                                                          Single
# cohorts                                                           10K
# data_type                                                     tabular
# debut                                                      2018-12-27
# pandas_dtype                                                    float
#
# tabular_field_name                                          cgm/range  \
# dataset                                                           cgm
# field_string                                                    Range
# description_string  Difference between the maximum and minimum glu...
# parent_dataframe                                                 <NA>
# relative_location                                     cgm/cgm.parquet
# value_type                                                 Continuous
# units                                                           mg/dl
# sampling_rate                                                    <NA>
# item_type                                                        Data
# array                                                          Single
# cohorts                                                           10K
# data_type                                                     tabular
# debut                                                      2018-12-27
# pandas_dtype                                                    float
#
# tabular_field_name                                     cgm/sd  \
# dataset                                                   cgm
# field_string                                               SD
# description_string  Standard deviation of all glucose values.
# parent_dataframe                                         <NA>
# relative_location                             cgm/cgm.parquet
# value_type                                         Continuous
# units                                                   mg/dl
# sampling_rate                                            <NA>
# item_type                                                Data
# array                                                  Single
# cohorts                                                   10K
# data_type                                             tabular
# debut                                              2018-12-27
# pandas_dtype                                            float
#
# tabular_field_name                                            cgm/sdb  \
# dataset                                                           cgm
# field_string                                                      SDb
# description_string  SD between days, within time points. Mean valu...
# parent_dataframe                                                 <NA>
# relative_location                                     cgm/cgm.parquet
# value_type                                                 Continuous
# units                                                           mg/dl
# sampling_rate                                                    <NA>
# item_type                                                        Data
# array                                                          Single
# cohorts                                                           10K
# data_type                                                     tabular
# debut                                                      2018-12-27
# pandas_dtype                                                    float
#
# tabular_field_name                                          cgm/sdbdm  \
# dataset                                                           cgm
# field_string                                                    SDbdm
# description_string  SD between days, within time points, corrected...
# parent_dataframe                                                 <NA>
# relative_location                                     cgm/cgm.parquet
# value_type                                                 Continuous
# units                                                           mg/dl
# sampling_rate                                                    <NA>
# item_type                                                        Data
# array                                                          Single
# cohorts                                                           10K
# data_type                                                     tabular
# debut                                                      2018-12-27
# pandas_dtype                                                    float
#
# tabular_field_name                                           cgm/sddm  \
# dataset                                                           cgm
# field_string                                                     SDdm
# description_string  Horizontal SD. SD of the mean glucose values, ...
# parent_dataframe                                                 <NA>
# relative_location                                     cgm/cgm.parquet
# value_type                                                 Continuous
# units                                                           mg/dl
# sampling_rate                                                    <NA>
# item_type                                                        Data
# array                                                          Single
# cohorts                                                           10K
# data_type                                                     tabular
# debut                                                      2018-12-27
# pandas_dtype                                                    float
#
# tabular_field_name                                         cgm/sdhhmm  \
# dataset                                                           cgm
# field_string                                                   SDhhmm
# description_string  SD between time points. Standard deviation of ...
# parent_dataframe                                                 <NA>
# relative_location                                     cgm/cgm.parquet
# value_type                                                 Continuous
# units                                                           mg/dl
# sampling_rate                                                    <NA>
# item_type                                                        Data
# array                                                          Single
# cohorts                                                           10K
# data_type                                                     tabular
# debut                                                      2018-12-27
# pandas_dtype                                                    float
#
# tabular_field_name                                            cgm/sdw  \
# dataset                                                           cgm
# field_string                                                      SDw
# description_string  Vertical SD within days. Average value of the ...
# parent_dataframe                                                 <NA>
# relative_location                                     cgm/cgm.parquet
# value_type                                                 Continuous
# units                                                           mg/dl
# sampling_rate                                                    <NA>
# item_type                                                        Data
# array                                                          Single
# cohorts                                                           10K
# data_type                                                     tabular
# debut                                                      2018-12-27
# pandas_dtype                                                    float
#
# tabular_field_name                                          cgm/sdwsh  \
# dataset                                                           cgm
# field_string                                                    SDwsh
# description_string  SD within series. Taking hour-long intervals t...
# parent_dataframe                                                 <NA>
# relative_location                                     cgm/cgm.parquet
# value_type                                                 Continuous
# units                                                           mg/dl
# sampling_rate                                                    <NA>
# item_type                                                        Data
# array                                                          Single
# cohorts                                                           10K
# data_type                                                     tabular
# debut                                                      2018-12-27
# pandas_dtype                                                    float
#
# tabular_field_name diet_logging/sodium_mg
# dataset                                   diet_logging
# field_string             Sodium intake per food logged
# description_string       Sodium intake per food logged
# parent_dataframe                                  <NA>
# relative_location    diet_logging/diet_logging.parquet
# value_type                                  Continuous
# units                                               mg
# sampling_rate                                     <NA>
# item_type                                         Data
# array                                           Single
# cohorts                                            10K
# data_type                                  Time Series
# debut                                       2019-09-01
# pandas_dtype                                     float
#
# [14 rows x 24 columns]

# %%
#| hide
import nbdev; nbdev.nbdev_export()
